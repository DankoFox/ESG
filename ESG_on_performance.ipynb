# %% [markdown]
# <a href="https://colab.research.google.com/github/DankoFox/ESG/blob/main/ESG_on_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1. IMPORT DATA

# %%
data = {
    "Variable": [
        "ESG scores", "E scores", "S scores", "G scores",
        "ROA", "ROE", "Profit margins", "Z index", "NPL/TA", "LLP/TA",
        "Liquidity coverage ratio", "Net stable funding ratio",
        "Capital Adequacy Ratio", "Leverage Ratio"
    ],
    2014: [91, 92, 86, 99, 0.0094, 0.1478, 0.2463, 45.0, 0.0194, 0.0013, 111, 100, 0.1206, 0.0441],
    2015: [87, 81, 85, 99, 0.0084, 0.1309, 0.2453, 44.7, 0.0175, 0.0013, 122, 100, 0.1347, 0.0490],
    2016: [90, 84, 90, 99, 0.0062, 0.0988, 0.1907, 42.7, 0.0183, 0.0021, 125, 105, 0.1421, 0.0510],
    2017: [89, 85, 90, 98, 0.0071, 0.1086, 0.2201, 44.8, 0.0193, 0.0013, 135, 110, 0.1476, 0.0550],
    2018: [88, 84, 87, 99, 0.0068, 0.1079, 0.2110, 42.8, 0.0184, 0.0007, 138, 115, 0.1493, 0.0530],
    2019: [87, 66, 88, 95, 0.0061, 0.0979, 0.1914, 41.8, 0.0126, 0.0008, 140, 116, 0.1502, 0.0530],
    2020: [86, 64, 88, 92, 0.0034, 0.0584, 0.1465, 38.3, 0.0067, 0.0026, 139, 124, 0.1671, 0.0540],
    2021: [86, 67, 86, 93, 0.0063, 0.0967, 0.3154, 43.9, 0.0054, -0.0006, 137, 124, 0.1778, 0.0510],
    2022: [84, 67, 83, 92, 0.0066, 0.1080, 0.3016, 41.3, 0.0041, -0.0002, 131, 119, 0.1794, 0.0530],
    2023: [86, 66, 87, 94, 0.0064, 0.1022, 0.1423, 42.6, 0.0000, 0.0002, 130, 116, 0.1794, 0.0510],
    2024: [87, 88, 84, 89, 0.0053, 0.0936, 0.1078, 38.2, 0.0055, 0.0003, 133, 116, 0.1945, 0.0440]
}

df_raw = pd.DataFrame(data)
df = df_raw.set_index("Variable").T
df.head()
# Out:
# Variable  ESG scores  E scores  S scores  G scores     ROA     ROE  \
# 2014            91.0      92.0      86.0      99.0  0.0094  0.1478
# 2015            87.0      81.0      85.0      99.0  0.0084  0.1309
# 2016            90.0      84.0      90.0      99.0  0.0062  0.0988
# 2017            89.0      85.0      90.0      98.0  0.0071  0.1086
# 2018            88.0      84.0      87.0      99.0  0.0068  0.1079
#
# Variable  Profit margins  Z index  NPL/TA  LLP/TA  Liquidity coverage ratio  \
# 2014              0.2463     45.0  0.0194  0.0013                     111.0
# 2015              0.2453     44.7  0.0175  0.0013                     122.0
# 2016              0.1907     42.7  0.0183  0.0021                     125.0
# 2017              0.2201     44.8  0.0193  0.0013                     135.0
# 2018              0.2110     42.8  0.0184  0.0007                     138.0
#
# Variable  Net stable funding ratio  Capital Adequacy Ratio  Leverage Ratio
# 2014                         100.0                  0.1206          0.0441
# 2015                         100.0                  0.1347          0.0490
# 2016                         105.0                  0.1421          0.0510
# 2017                         110.0                  0.1476          0.0550
# 2018                         115.0                  0.1493          0.0530

# %% [markdown]
# *3*. Create Lagged Variables
# To check for delayed effects (e.g., whether ESG scores from year t-1 affect ROA in year t), we need to lag the independent variables.

# %% [markdown]
# - ESG scores → current year → short-term impact
# - ESG_Lag1 → 1 year lag → short to mid-term impact
# - ESG_Lag2 → 2 years lag → mid-term impact
# - ESG_Lag3 → 3 years lag → long-term impact

# %%
# Step 1: Start from the original raw DataFrame
df_raw = df.copy()  # Keep unlagged version

# Step 2: ESG lagged model base
df_esg = df_raw.copy()
df_esg["ESG_Lag1"] = df_esg["ESG scores"].shift(1)
df_esg["ESG_Lag2"] = df_esg["ESG scores"].shift(2)
df_esg["ESG_Lag3"] = df_esg["ESG scores"].shift(3)
df_esg = df_esg.dropna()

# Step 3: E-only model
df_E = df_raw.copy()
df_E["E_Lag1"] = df_E["E scores"].shift(1)
df_E["E_Lag2"] = df_E["E scores"].shift(2)
df_E["E_Lag3"] = df_E["E scores"].shift(3)
df_E = df_E.dropna()

# Step 4: S-only model
df_S = df_raw.copy()
df_S["S_Lag1"] = df_S["S scores"].shift(1)
df_S["S_Lag2"] = df_S["S scores"].shift(2)
df_S["S_Lag3"] = df_S["S scores"].shift(3)
df_S = df_S.dropna()

# Step 5: G-only model
df_G = df_raw.copy()
df_G["G_Lag1"] = df_G["G scores"].shift(1)
df_G["G_Lag2"] = df_G["G scores"].shift(2)
df_G["G_Lag3"] = df_G["G scores"].shift(3)
df_G = df_G.dropna()

# %%
df_esg
# Out:
# Variable  ESG scores  E scores  S scores  G scores     ROA     ROE  \
# 2017            89.0      85.0      90.0      98.0  0.0071  0.1086
# 2018            88.0      84.0      87.0      99.0  0.0068  0.1079
# 2019            87.0      66.0      88.0      95.0  0.0061  0.0979
# 2020            86.0      64.0      88.0      92.0  0.0034  0.0584
# 2021            86.0      67.0      86.0      93.0  0.0063  0.0967
# 2022            84.0      67.0      83.0      92.0  0.0066  0.1080
# 2023            86.0      66.0      87.0      94.0  0.0064  0.1022
# 2024            87.0      88.0      84.0      89.0  0.0053  0.0936
#
# Variable  Profit margins  Z index  NPL/TA  LLP/TA  Liquidity coverage ratio  \
# 2017              0.2201     44.8  0.0193  0.0013                     135.0
# 2018              0.2110     42.8  0.0184  0.0007                     138.0
# 2019              0.1914     41.8  0.0126  0.0008                     140.0
# 2020              0.1465     38.3  0.0067  0.0026                     139.0
# 2021              0.3154     43.9  0.0054 -0.0006                     137.0
# 2022              0.3016     41.3  0.0041 -0.0002                     131.0
# 2023              0.1423     42.6  0.0000  0.0002                     130.0
# 2024              0.1078     38.2  0.0055  0.0003                     133.0
#
# Variable  Net stable funding ratio  Capital Adequacy Ratio  Leverage Ratio  \
# 2017                         110.0                  0.1476           0.055
# 2018                         115.0                  0.1493           0.053
# 2019                         116.0                  0.1502           0.053
# 2020                         124.0                  0.1671           0.054
# 2021                         124.0                  0.1778           0.051
# 2022                         119.0                  0.1794           0.053
# 2023                         116.0                  0.1794           0.051
# 2024                         116.0                  0.1945           0.044
#
# Variable  ESG_Lag1  ESG_Lag2  ESG_Lag3
# 2017          90.0      87.0      91.0
# 2018          89.0      90.0      87.0
# 2019          88.0      89.0      90.0
# 2020          87.0      88.0      89.0
# 2021          86.0      87.0      88.0
# 2022          86.0      86.0      87.0
# 2023          84.0      86.0      86.0
# 2024          86.0      84.0      86.0

# %%
import statsmodels.api as sm

def run_regression(y_var, x_vars, data):
    X = data[x_vars]
    X = sm.add_constant(X)  # adds intercept
    y = data[y_var]
    model = sm.OLS(y, X).fit()
    return model

# %% [markdown]
# ### ESG chung

# %%
regression_targets = [
    "ROA",
    "ROE",
    "Profit margins",
    "Z index",
    "NPL/TA",
    "LLP/TA",
    "Liquidity coverage ratio",
    "Net stable funding ratio",
    "Capital Adequacy Ratio",
    "Leverage Ratio"
]

for target in regression_targets:
    model = run_regression(target, ["ESG scores", "ESG_Lag1", "ESG_Lag2", "ESG_Lag3"], df_esg)
    print(f"\n--- {target} Regression ---")
    print(model.summary())
# Out:
# --- ROA Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROA   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                 -1.070
# Method:                 Least Squares   F-statistic:                   0.09531
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.977
# Time:                        16:47:51   Log-Likelihood:                 43.610
# No. Observations:                   8   AIC:                            -77.22
# Df Residuals:                       3   BIC:                            -76.82
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.046     -0.055      0.960      -0.148       0.143
# ESG scores  9.183e-05      0.001      0.141      0.897      -0.002       0.002
# ESG_Lag1       0.0002      0.001      0.340      0.756      -0.002       0.003
# ESG_Lag2   -3.996e-05      0.000     -0.093      0.932      -0.001       0.001
# ESG_Lag3      -0.0002      0.001     -0.384      0.726      -0.002       0.001
# ==============================================================================
# Omnibus:                        6.489   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                2.327
# Skew:                          -1.311   Prob(JB):                        0.312
# Kurtosis:                       3.325   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- ROE Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROE   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                 -0.938
# Method:                 Least Squares   F-statistic:                    0.1532
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.949
# Time:                        16:47:51   Log-Likelihood:                 22.767
# No. Observations:                   8   AIC:                            -35.53
# Df Residuals:                       3   BIC:                            -35.14
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1375      0.620      0.222      0.839      -1.836       2.111
# ESG scores     0.0006      0.009      0.067      0.951      -0.028       0.029
# ESG_Lag1       0.0049      0.010      0.505      0.648      -0.026       0.036
# ESG_Lag2      -0.0016      0.006     -0.272      0.803      -0.020       0.017
# ESG_Lag3      -0.0043      0.007     -0.630      0.574      -0.026       0.017
# ==============================================================================
# Omnibus:                        8.006   Durbin-Watson:                   2.294
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                2.772
# Skew:                          -1.406   Prob(JB):                        0.250
# Kurtosis:                       3.636   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Profit margins Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Profit margins   R-squared:                       0.371
# Model:                            OLS   Adj. R-squared:                 -0.467
# Method:                 Least Squares   F-statistic:                    0.4432
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.776
# Time:                        16:47:51   Log-Likelihood:                 11.824
# No. Observations:                   8   AIC:                            -13.65
# Df Residuals:                       3   BIC:                            -13.25
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2224      2.435      0.502      0.650      -6.528       8.972
# ESG scores    -0.0426      0.035     -1.229      0.307      -0.153       0.068
# ESG_Lag1       0.0266      0.038      0.699      0.535      -0.094       0.147
# ESG_Lag2       0.0013      0.023      0.057      0.958      -0.072       0.074
# ESG_Lag3       0.0028      0.027      0.105      0.923      -0.083       0.088
# ==============================================================================
# Omnibus:                        1.465   Durbin-Watson:                   2.312
# Prob(Omnibus):                  0.481   Jarque-Bera (JB):                0.249
# Skew:                           0.432   Prob(JB):                        0.883
# Kurtosis:                       2.952   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Z index Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Z index   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                 -0.867
# Method:                 Least Squares   F-statistic:                    0.1874
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.930
# Time:                        16:47:51   Log-Likelihood:                -16.942
# No. Observations:                   8   AIC:                             43.88
# Df Residuals:                       3   BIC:                             44.28
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -33.8946     88.747     -0.382      0.728    -316.328     248.539
# ESG scores     0.5375      1.264      0.425      0.699      -3.484       4.559
# ESG_Lag1      -0.3090      1.384     -0.223      0.838      -4.715       4.097
# ESG_Lag2       0.3078      0.834      0.369      0.737      -2.347       2.963
# ESG_Lag3       0.3308      0.978      0.338      0.758      -2.783       3.444
# ==============================================================================
# Omnibus:                        1.368   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.505   Jarque-Bera (JB):                0.920
# Skew:                          -0.656   Prob(JB):                        0.631
# Kurtosis:                       1.981   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- NPL/TA Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NPL/TA   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     73.76
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):            0.00251
# Time:                        16:47:51   Log-Likelihood:                 47.273
# No. Observations:                   8   AIC:                            -84.55
# Df Residuals:                       3   BIC:                            -84.15
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3318      0.029    -11.449      0.001      -0.424      -0.240
# ESG scores     0.0009      0.000      2.178      0.118      -0.000       0.002
# ESG_Lag1       0.0032      0.000      7.058      0.006       0.002       0.005
# ESG_Lag2       0.0004      0.000      1.505      0.229      -0.000       0.001
# ESG_Lag3      -0.0006      0.000     -1.792      0.171      -0.002       0.000
# ==============================================================================
# Omnibus:                        8.750   Durbin-Watson:                   2.378
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                2.999
# Skew:                          -1.446   Prob(JB):                        0.223
# Kurtosis:                       3.794   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- LLP/TA Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 LLP/TA   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                 -0.639
# Method:                 Least Squares   F-statistic:                    0.3179
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.851
# Time:                        16:47:51   Log-Likelihood:                 45.940
# No. Observations:                   8   AIC:                            -81.88
# Df Residuals:                       3   BIC:                            -81.48
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0319      0.034     -0.931      0.421      -0.141       0.077
# ESG scores  8.941e-05      0.000      0.183      0.866      -0.001       0.002
# ESG_Lag1   -2.063e-05      0.001     -0.039      0.972      -0.002       0.002
# ESG_Lag2    8.448e-05      0.000      0.262      0.810      -0.001       0.001
# ESG_Lag3       0.0002      0.000      0.578      0.604      -0.001       0.001
# ==============================================================================
# Omnibus:                        5.346   Durbin-Watson:                   2.986
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                1.279
# Skew:                           0.899   Prob(JB):                        0.527
# Kurtosis:                       3.777   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Liquidity coverage ratio Regression ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Liquidity coverage ratio   R-squared:                       0.667
# Model:                                  OLS   Adj. R-squared:                  0.222
# Method:                       Least Squares   F-statistic:                     1.499
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.385
# Time:                              16:47:51   Log-Likelihood:                -16.976
# No. Observations:                         8   AIC:                             43.95
# Df Residuals:                             3   BIC:                             44.35
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -38.3371     89.127     -0.430      0.696    -321.980     245.306
# ESG scores     0.2239      1.269      0.176      0.871      -3.815       4.263
# ESG_Lag1      -0.1674      1.390     -0.120      0.912      -4.592       4.257
# ESG_Lag2       1.2584      0.838      1.502      0.230      -1.408       3.925
# ESG_Lag3       0.6731      0.983      0.685      0.542      -2.454       3.800
# ==============================================================================
# Omnibus:                        2.488   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.288   Jarque-Bera (JB):                0.846
# Skew:                          -0.175   Prob(JB):                        0.655
# Kurtosis:                       1.446   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Net stable funding ratio Regression ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Net stable funding ratio   R-squared:                       0.551
# Model:                                  OLS   Adj. R-squared:                 -0.048
# Method:                       Least Squares   F-statistic:                    0.9201
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.550
# Time:                              16:47:51   Log-Likelihood:                -20.031
# No. Observations:                         8   AIC:                             50.06
# Df Residuals:                             3   BIC:                             50.46
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        238.8212    130.573      1.829      0.165    -176.719     654.362
# ESG scores    -1.7832      1.859     -0.959      0.408      -7.700       4.134
# ESG_Lag1      -1.0484      2.037     -0.515      0.642      -7.531       5.434
# ESG_Lag2       0.8616      1.227      0.702      0.533      -3.045       4.768
# ESG_Lag3       0.5601      1.439      0.389      0.723      -4.021       5.141
# ==============================================================================
# Omnibus:                        1.907   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.385   Jarque-Bera (JB):                0.847
# Skew:                           0.350   Prob(JB):                        0.655
# Kurtosis:                       1.568   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Capital Adequacy Ratio Regression ---
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Capital Adequacy Ratio   R-squared:                       0.933
# Model:                                OLS   Adj. R-squared:                  0.844
# Method:                     Least Squares   F-statistic:                     10.44
# Date:                    Thu, 05 Jun 2025   Prob (F-statistic):             0.0416
# Time:                            16:47:51   Log-Likelihood:                 32.362
# No. Observations:                       8   AIC:                            -54.72
# Df Residuals:                           3   BIC:                            -54.33
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1627      0.187      6.221      0.008       0.568       1.758
# ESG scores    -0.0020      0.003     -0.743      0.511      -0.010       0.006
# ESG_Lag1      -0.0018      0.003     -0.618      0.580      -0.011       0.007
# ESG_Lag2      -0.0052      0.002     -2.935      0.061      -0.011       0.000
# ESG_Lag3      -0.0025      0.002     -1.198      0.317      -0.009       0.004
# ==============================================================================
# Omnibus:                        1.835   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.400   Jarque-Bera (JB):                0.730
# Skew:                           0.067   Prob(JB):                        0.694
# Kurtosis:                       1.526   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Leverage Ratio Regression ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Leverage Ratio   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.359
# Method:                 Least Squares   F-statistic:                     1.981
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.300
# Time:                        16:47:51   Log-Likelihood:                 39.796
# No. Observations:                   8   AIC:                            -69.59
# Df Residuals:                       3   BIC:                            -69.19
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0543      0.074     -0.736      0.515      -0.289       0.181
# ESG scores    -0.0009      0.001     -0.859      0.454      -0.004       0.002
# ESG_Lag1       0.0002      0.001      0.161      0.882      -0.003       0.004
# ESG_Lag2       0.0009      0.001      1.362      0.267      -0.001       0.003
# ESG_Lag3       0.0010      0.001      1.198      0.317      -0.002       0.004
# ==============================================================================
# Omnibus:                        1.165   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                0.627
# Skew:                          -0.128   Prob(JB):                        0.731
# Kurtosis:                       1.652   Cond. No.                     1.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# ### E - Individual

# %%
for target in regression_targets:
    model = run_regression(target, ["E scores", "E_Lag1", "E_Lag2", "E_Lag3"], df_E)
    print(f"\n--- {target} Regression (Environmental - E) ---")
    print(model.summary())
# Out:
# --- ROA Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROA   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     15.13
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0249
# Time:                        16:49:25   Log-Likelihood:                 55.342
# No. Observations:                   8   AIC:                            -100.7
# Df Residuals:                       3   BIC:                            -100.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0055      0.002      3.552      0.038       0.001       0.010
# E scores   -1.819e-05   1.65e-05     -1.100      0.352   -7.08e-05    3.44e-05
# E_Lag1         0.0002   2.66e-05      7.034      0.006       0.000       0.000
# E_Lag2        -0.0002   2.97e-05     -6.186      0.009      -0.000   -8.93e-05
# E_Lag3      2.538e-05   2.04e-05      1.247      0.301   -3.94e-05    9.01e-05
# ==============================================================================
# Omnibus:                        0.259   Durbin-Watson:                   2.935
# Prob(Omnibus):                  0.879   Jarque-Bera (JB):                0.391
# Skew:                          -0.163   Prob(JB):                        0.822
# Kurtosis:                       1.967   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- ROE Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROE   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     42.14
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):            0.00572
# Time:                        16:49:25   Log-Likelihood:                 38.209
# No. Observations:                   8   AIC:                            -66.42
# Df Residuals:                       3   BIC:                            -66.02
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0965      0.013      7.369      0.005       0.055       0.138
# E scores   -9.837e-05      0.000     -0.699      0.535      -0.001       0.000
# E_Lag1         0.0025      0.000     11.225      0.002       0.002       0.003
# E_Lag2        -0.0024      0.000     -9.476      0.002      -0.003      -0.002
# E_Lag3      1.653e-05      0.000      0.095      0.930      -0.001       0.001
# ==============================================================================
# Omnibus:                        0.063   Durbin-Watson:                   2.863
# Prob(Omnibus):                  0.969   Jarque-Bera (JB):                0.132
# Skew:                          -0.048   Prob(JB):                        0.936
# Kurtosis:                       2.378   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Profit margins Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Profit margins   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     1.631
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.358
# Time:                        16:49:25   Log-Likelihood:                 14.588
# No. Observations:                   8   AIC:                            -19.18
# Df Residuals:                       3   BIC:                            -18.78
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3820      0.251      1.523      0.225      -0.416       1.180
# E scores      -0.0036      0.003     -1.317      0.279      -0.012       0.005
# E_Lag1         0.0061      0.004      1.411      0.253      -0.008       0.020
# E_Lag2        -0.0112      0.005     -2.310      0.104      -0.027       0.004
# E_Lag3         0.0061      0.003      1.833      0.164      -0.004       0.017
# ==============================================================================
# Omnibus:                        0.815   Durbin-Watson:                   2.721
# Prob(Omnibus):                  0.665   Jarque-Bera (JB):                0.630
# Skew:                           0.381   Prob(JB):                        0.730
# Kurtosis:                       1.855   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Z index Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Z index   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     3.066
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.192
# Time:                        16:49:25   Log-Likelihood:                -11.327
# No. Observations:                   8   AIC:                             32.65
# Df Residuals:                       3   BIC:                             33.05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.3555      6.401      5.992      0.009      17.984      58.727
# E scores      -0.0827      0.069     -1.202      0.316      -0.302       0.136
# E_Lag1         0.3141      0.111      2.837      0.066      -0.038       0.666
# E_Lag2        -0.3598      0.124     -2.909      0.062      -0.753       0.034
# E_Lag3         0.1725      0.085      2.037      0.134      -0.097       0.442
# ==============================================================================
# Omnibus:                        0.318   Durbin-Watson:                   3.018
# Prob(Omnibus):                  0.853   Jarque-Bera (JB):                0.417
# Skew:                           0.186   Prob(JB):                        0.812
# Kurtosis:                       1.945   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- NPL/TA Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NPL/TA   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     24.68
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0124
# Time:                        16:49:25   Log-Likelihood:                 42.973
# No. Observations:                   8   AIC:                            -75.95
# Df Residuals:                       3   BIC:                            -75.55
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0569      0.007     -7.880      0.004      -0.080      -0.034
# E scores       0.0002   7.76e-05      2.672      0.076   -3.96e-05       0.000
# E_Lag1         0.0004      0.000      3.252      0.047    8.74e-06       0.001
# E_Lag2      1.476e-05      0.000      0.106      0.922      -0.000       0.000
# E_Lag3         0.0003   9.55e-05      2.685      0.075   -4.75e-05       0.001
# ==============================================================================
# Omnibus:                        0.867   Durbin-Watson:                   2.791
# Prob(Omnibus):                  0.648   Jarque-Bera (JB):                0.679
# Skew:                           0.511   Prob(JB):                        0.712
# Kurtosis:                       2.003   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- LLP/TA Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 LLP/TA   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     4.065
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.139
# Time:                        16:49:25   Log-Likelihood:                 51.964
# No. Observations:                   8   AIC:                            -93.93
# Df Residuals:                       3   BIC:                            -93.53
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0049      0.002     -2.079      0.129      -0.012       0.003
# E scores    1.825e-05   2.52e-05      0.723      0.522    -6.2e-05    9.85e-05
# E_Lag1     -8.727e-05   4.06e-05     -2.150      0.121      -0.000    4.19e-05
# E_Lag2         0.0002   4.53e-05      3.383      0.043    9.07e-06       0.000
# E_Lag3      -1.19e-05    3.1e-05     -0.383      0.727      -0.000    8.69e-05
# ==============================================================================
# Omnibus:                        0.454   Durbin-Watson:                   2.411
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.465
# Skew:                           0.174   Prob(JB):                        0.793
# Kurtosis:                       1.871   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Liquidity coverage ratio Regression (Environmental - E) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Liquidity coverage ratio   R-squared:                       0.772
# Model:                                  OLS   Adj. R-squared:                  0.467
# Method:                       Least Squares   F-statistic:                     2.535
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.235
# Time:                              16:49:25   Log-Likelihood:                -15.460
# No. Observations:                         8   AIC:                             40.92
# Df Residuals:                             3   BIC:                             41.32
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        113.1596     10.731     10.545      0.002      79.008     147.312
# E scores      -0.0359      0.115     -0.311      0.776      -0.403       0.331
# E_Lag1        -0.0925      0.186     -0.498      0.653      -0.683       0.498
# E_Lag2         0.2536      0.207      1.223      0.309      -0.406       0.913
# E_Lag3         0.1622      0.142      1.143      0.336      -0.290       0.614
# ==============================================================================
# Omnibus:                        1.538   Durbin-Watson:                   2.178
# Prob(Omnibus):                  0.463   Jarque-Bera (JB):                0.810
# Skew:                          -0.396   Prob(JB):                        0.667
# Kurtosis:                       1.657   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Net stable funding ratio Regression (Environmental - E) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Net stable funding ratio   R-squared:                       0.806
# Model:                                  OLS   Adj. R-squared:                  0.546
# Method:                       Least Squares   F-statistic:                     3.107
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.189
# Time:                              16:49:25   Log-Likelihood:                -16.683
# No. Observations:                         8   AIC:                             43.37
# Df Residuals:                             3   BIC:                             43.76
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        142.2089     12.503     11.374      0.001     102.418     181.999
# E scores      -0.1559      0.134     -1.160      0.330      -0.584       0.272
# E_Lag1        -0.4677      0.216     -2.163      0.119      -1.156       0.221
# E_Lag2         0.1527      0.242      0.632      0.572      -0.616       0.922
# E_Lag3         0.1208      0.165      0.730      0.518      -0.406       0.647
# ==============================================================================
# Omnibus:                        0.158   Durbin-Watson:                   2.362
# Prob(Omnibus):                  0.924   Jarque-Bera (JB):                0.331
# Skew:                          -0.194   Prob(JB):                        0.848
# Kurtosis:                       2.083   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Capital Adequacy Ratio Regression (Environmental - E) ---
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Capital Adequacy Ratio   R-squared:                       0.967
# Model:                                OLS   Adj. R-squared:                  0.922
# Method:                     Least Squares   F-statistic:                     21.69
# Date:                    Thu, 05 Jun 2025   Prob (F-statistic):             0.0150
# Time:                            16:49:25   Log-Likelihood:                 35.145
# No. Observations:                       8   AIC:                            -60.29
# Df Residuals:                           3   BIC:                            -59.89
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2912      0.019     15.160      0.001       0.230       0.352
# E scores       0.0004      0.000      1.987      0.141      -0.000       0.001
# E_Lag1        -0.0014      0.000     -4.175      0.025      -0.002      -0.000
# E_Lag2        -0.0002      0.000     -0.560      0.615      -0.001       0.001
# E_Lag3        -0.0005      0.000     -1.845      0.162      -0.001       0.000
# ==============================================================================
# Omnibus:                        2.016   Durbin-Watson:                   2.448
# Prob(Omnibus):                  0.365   Jarque-Bera (JB):                1.223
# Skew:                           0.840   Prob(JB):                        0.543
# Kurtosis:                       2.082   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Leverage Ratio Regression (Environmental - E) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Leverage Ratio   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     1.589
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.367
# Time:                        16:49:25   Log-Likelihood:                 39.175
# No. Observations:                   8   AIC:                            -68.35
# Df Residuals:                       3   BIC:                            -67.95
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0446      0.012      3.843      0.031       0.008       0.082
# E scores      -0.0002      0.000     -1.661      0.195      -0.001       0.000
# E_Lag1         0.0002      0.000      1.033      0.378      -0.000       0.001
# E_Lag2     -3.712e-05      0.000     -0.166      0.879      -0.001       0.001
# E_Lag3         0.0001      0.000      0.838      0.463      -0.000       0.001
# ==============================================================================
# Omnibus:                        1.412   Durbin-Watson:                   2.397
# Prob(Omnibus):                  0.494   Jarque-Bera (JB):                0.801
# Skew:                          -0.424   Prob(JB):                        0.670
# Kurtosis:                       1.701   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# ### S - Individual

# %%
for target in regression_targets:
    model = run_regression(target, ["S scores", "S_Lag1", "S_Lag2", "S_Lag3"], df_S)
    print(f"\n--- {target} Regression (Social - S) ---")
    print(model.summary())
# Out:
# --- ROA Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROA   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     1.130
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.479
# Time:                        16:49:33   Log-Likelihood:                 46.808
# No. Observations:                   8   AIC:                            -83.62
# Df Residuals:                       3   BIC:                            -83.22
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0498      0.035      1.443      0.245      -0.060       0.160
# S scores       0.0001      0.000      0.663      0.555      -0.001       0.001
# S_Lag1        -0.0003      0.000     -1.108      0.349      -0.001       0.001
# S_Lag2         0.0003      0.000      1.274      0.292      -0.000       0.001
# S_Lag3        -0.0006      0.000     -2.058      0.132      -0.002       0.000
# ==============================================================================
# Omnibus:                        1.143   Durbin-Watson:                   2.769
# Prob(Omnibus):                  0.565   Jarque-Bera (JB):                0.610
# Skew:                          -0.005   Prob(JB):                        0.737
# Kurtosis:                       1.647   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- ROE Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROE   R-squared:                       0.601
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     1.131
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.479
# Time:                        16:49:33   Log-Likelihood:                 25.702
# No. Observations:                   8   AIC:                            -41.40
# Df Residuals:                       3   BIC:                            -41.01
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8398      0.483      1.739      0.180      -0.697       2.377
# S scores       0.0010      0.003      0.321      0.769      -0.009       0.011
# S_Lag1        -0.0040      0.004     -1.118      0.345      -0.015       0.007
# S_Lag2         0.0031      0.003      1.125      0.342      -0.006       0.012
# S_Lag3        -0.0086      0.004     -2.057      0.132      -0.022       0.005
# ==============================================================================
# Omnibus:                        1.171   Durbin-Watson:                   2.839
# Prob(Omnibus):                  0.557   Jarque-Bera (JB):                0.616
# Skew:                           0.034   Prob(JB):                        0.735
# Kurtosis:                       1.642   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Profit margins Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Profit margins   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                 -0.455
# Method:                 Least Squares   F-statistic:                    0.4529
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.770
# Time:                        16:49:33   Log-Likelihood:                 11.856
# No. Observations:                   8   AIC:                            -13.71
# Df Residuals:                       3   BIC:                            -13.32
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4380      2.726     -0.161      0.883      -9.114       8.238
# S scores      -0.0108      0.017     -0.618      0.580      -0.066       0.045
# S_Lag1         0.0072      0.020      0.354      0.747      -0.057       0.072
# S_Lag2         0.0158      0.016      1.020      0.383      -0.034       0.065
# S_Lag3        -0.0049      0.023     -0.209      0.848      -0.080       0.070
# ==============================================================================
# Omnibus:                        2.243   Durbin-Watson:                   1.607
# Prob(Omnibus):                  0.326   Jarque-Bera (JB):                0.850
# Skew:                           0.266   Prob(JB):                        0.654
# Kurtosis:                       1.494   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Z index Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Z index   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     1.123
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.481
# Time:                        16:49:33   Log-Likelihood:                -14.173
# No. Observations:                   8   AIC:                             38.35
# Df Residuals:                       3   BIC:                             38.74
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         68.0614     70.566      0.965      0.406    -156.511     292.634
# S scores       0.6666      0.452      1.476      0.236      -0.771       2.104
# S_Lag1        -0.4770      0.523     -0.911      0.429      -2.143       1.189
# S_Lag2         0.5138      0.402      1.278      0.291      -0.766       1.793
# S_Lag3        -0.9963      0.608     -1.639      0.200      -2.931       0.938
# ==============================================================================
# Omnibus:                        2.618   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.270   Jarque-Bera (JB):                0.847
# Skew:                           0.122   Prob(JB):                        0.655
# Kurtosis:                       1.425   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- NPL/TA Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NPL/TA   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     4.443
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.125
# Time:                        16:49:33   Log-Likelihood:                 36.618
# No. Observations:                   8   AIC:                            -63.24
# Df Residuals:                       3   BIC:                            -62.84
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2090      0.123     -1.694      0.189      -0.602       0.184
# S scores       0.0012      0.001      1.508      0.229      -0.001       0.004
# S_Lag1         0.0017      0.001      1.855      0.161      -0.001       0.005
# S_Lag2         0.0006      0.001      0.864      0.451      -0.002       0.003
# S_Lag3        -0.0010      0.001     -0.930      0.421      -0.004       0.002
# ==============================================================================
# Omnibus:                        1.618   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.445   Jarque-Bera (JB):                0.754
# Skew:                          -0.713   Prob(JB):                        0.686
# Kurtosis:                       2.523   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- LLP/TA Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 LLP/TA   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     1.565
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.371
# Time:                        16:49:33   Log-Likelihood:                 49.034
# No. Observations:                   8   AIC:                            -88.07
# Df Residuals:                       3   BIC:                            -87.67
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0515      0.026     -1.969      0.144      -0.135       0.032
# S scores       0.0002      0.000      0.964      0.406      -0.000       0.001
# S_Lag1         0.0002      0.000      1.231      0.306      -0.000       0.001
# S_Lag2        -0.0002      0.000     -1.016      0.384      -0.001       0.000
# S_Lag3         0.0003      0.000      1.546      0.220      -0.000       0.001
# ==============================================================================
# Omnibus:                        0.288   Durbin-Watson:                   3.277
# Prob(Omnibus):                  0.866   Jarque-Bera (JB):                0.295
# Skew:                          -0.311   Prob(JB):                        0.863
# Kurtosis:                       2.294   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Liquidity coverage ratio Regression (Social - S) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Liquidity coverage ratio   R-squared:                       0.818
# Model:                                  OLS   Adj. R-squared:                  0.576
# Method:                       Least Squares   F-statistic:                     3.375
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.173
# Time:                              16:49:33   Log-Likelihood:                -14.549
# No. Observations:                         8   AIC:                             39.10
# Df Residuals:                             3   BIC:                             39.50
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -114.0334     73.965     -1.542      0.221    -349.422     121.355
# S scores       0.2020      0.473      0.427      0.698      -1.305       1.709
# S_Lag1         1.2447      0.549      2.268      0.108      -0.501       2.991
# S_Lag2         0.4175      0.421      0.991      0.395      -0.924       1.759
# S_Lag3         0.9918      0.637      1.557      0.217      -1.036       3.019
# ==============================================================================
# Omnibus:                        1.600   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.449   Jarque-Bera (JB):                0.940
# Skew:                          -0.756   Prob(JB):                        0.625
# Kurtosis:                       2.268   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Net stable funding ratio Regression (Social - S) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Net stable funding ratio   R-squared:                       0.462
# Model:                                  OLS   Adj. R-squared:                 -0.256
# Method:                       Least Squares   F-statistic:                    0.6437
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.668
# Time:                              16:49:33   Log-Likelihood:                -20.755
# No. Observations:                         8   AIC:                             51.51
# Df Residuals:                             3   BIC:                             51.91
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1833    160.654      0.007      0.995    -510.089     512.456
# S scores      -1.1537      1.028     -1.122      0.344      -4.427       2.119
# S_Lag1         0.6713      1.192      0.563      0.613      -3.122       4.464
# S_Lag2         0.1169      0.915      0.128      0.906      -2.796       3.030
# S_Lag3         1.6848      1.384      1.218      0.310      -2.719       6.089
# ==============================================================================
# Omnibus:                        0.930   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.628   Jarque-Bera (JB):                0.649
# Skew:                           0.575   Prob(JB):                        0.723
# Kurtosis:                       2.209   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Capital Adequacy Ratio Regression (Social - S) ---
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Capital Adequacy Ratio   R-squared:                       0.893
# Model:                                OLS   Adj. R-squared:                  0.750
# Method:                     Least Squares   F-statistic:                     6.254
# Date:                    Thu, 05 Jun 2025   Prob (F-statistic):             0.0820
# Time:                            16:49:33   Log-Likelihood:                 30.488
# No. Observations:                       8   AIC:                            -50.98
# Df Residuals:                           3   BIC:                            -50.58
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9643      0.266      3.632      0.036       0.119       1.809
# S scores      -0.0050      0.002     -2.928      0.061      -0.010       0.000
# S_Lag1        -0.0017      0.002     -0.865      0.451      -0.008       0.005
# S_Lag2        -0.0034      0.002     -2.264      0.109      -0.008       0.001
# S_Lag3         0.0009      0.002      0.411      0.708      -0.006       0.008
# ==============================================================================
# Omnibus:                        2.128   Durbin-Watson:                   2.332
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                0.762
# Skew:                           0.747   Prob(JB):                        0.683
# Kurtosis:                       2.768   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Leverage Ratio Regression (Social - S) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Leverage Ratio   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     1.290
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.434
# Time:                        16:49:33   Log-Likelihood:                 38.628
# No. Observations:                   8   AIC:                            -67.26
# Df Residuals:                       3   BIC:                            -66.86
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1073      0.096     -1.118      0.345      -0.413       0.198
# S scores       0.0007      0.001      1.185      0.321      -0.001       0.003
# S_Lag1         0.0002      0.001      0.226      0.835      -0.002       0.002
# S_Lag2         0.0006      0.001      1.187      0.321      -0.001       0.002
# S_Lag3         0.0003      0.001      0.350      0.749      -0.002       0.003
# ==============================================================================
# Omnibus:                        0.327   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.849   Jarque-Bera (JB):                0.410
# Skew:                           0.314   Prob(JB):                        0.815
# Kurtosis:                       2.087   Cond. No.                     1.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# ### G - Individual

# %%
for target in regression_targets:
    model = run_regression(target, ["G scores", "G_Lag1", "G_Lag2", "G_Lag3"], df_G)
    print(f"\n--- {target} Regression (Governance - G) ---")
    print(model.summary())
# Out:
# --- ROA Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROA   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     26.37
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0113
# Time:                        16:51:02   Log-Likelihood:                 57.484
# No. Observations:                   8   AIC:                            -105.0
# Df Residuals:                       3   BIC:                            -104.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0092      0.004     -2.221      0.113      -0.022       0.004
# G scores       0.0004   5.02e-05      8.515      0.003       0.000       0.001
# G_Lag1         0.0001   6.32e-05      2.062      0.131   -7.09e-05       0.000
# G_Lag2        -0.0006   8.17e-05     -7.368      0.005      -0.001      -0.000
# G_Lag3         0.0002   6.91e-05      3.043      0.056   -9.64e-06       0.000
# ==============================================================================
# Omnibus:                        0.039   Durbin-Watson:                   2.725
# Prob(Omnibus):                  0.981   Jarque-Bera (JB):                0.271
# Skew:                          -0.005   Prob(JB):                        0.873
# Kurtosis:                       2.099   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- ROE Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ROE   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     74.41
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):            0.00248
# Time:                        16:51:02   Log-Likelihood:                 40.453
# No. Observations:                   8   AIC:                            -70.91
# Df Residuals:                       3   BIC:                            -70.51
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0519      0.035     -1.492      0.233      -0.163       0.059
# G scores       0.0055      0.000     13.026      0.001       0.004       0.007
# G_Lag1         0.0029      0.001      5.450      0.012       0.001       0.005
# G_Lag2        -0.0092      0.001    -13.337      0.001      -0.011      -0.007
# G_Lag3         0.0024      0.001      4.175      0.025       0.001       0.004
# ==============================================================================
# Omnibus:                        1.007   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                0.587
# Skew:                           0.063   Prob(JB):                        0.746
# Kurtosis:                       1.680   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Profit margins Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Profit margins   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     6.672
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0754
# Time:                        16:51:02   Log-Likelihood:                 19.135
# No. Observations:                   8   AIC:                            -28.27
# Df Residuals:                       3   BIC:                            -27.87
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6892      0.500     -1.379      0.262      -2.280       0.901
# G scores       0.0128      0.006      2.113      0.125      -0.006       0.032
# G_Lag1        -0.0097      0.008     -1.272      0.293      -0.034       0.015
# G_Lag2        -0.0319      0.010     -3.236      0.048      -0.063      -0.001
# G_Lag3         0.0380      0.008      4.557      0.020       0.011       0.065
# ==============================================================================
# Omnibus:                        1.348   Durbin-Watson:                   2.608
# Prob(Omnibus):                  0.510   Jarque-Bera (JB):                0.764
# Skew:                           0.684   Prob(JB):                        0.682
# Kurtosis:                       2.350   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Z index Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Z index   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     3.863
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.148
# Time:                        16:51:02   Log-Likelihood:                -10.568
# No. Observations:                   8   AIC:                             31.14
# Df Residuals:                       3   BIC:                             31.53
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.3593     20.473     -0.164      0.880     -68.514      61.795
# G scores       0.8589      0.248      3.460      0.041       0.069       1.649
# G_Lag1        -0.2350      0.313     -0.751      0.507      -1.230       0.760
# G_Lag2        -0.6344      0.404     -1.569      0.215      -1.921       0.652
# G_Lag3         0.4913      0.342      1.438      0.246      -0.596       1.579
# ==============================================================================
# Omnibus:                        0.384   Durbin-Watson:                   3.050
# Prob(Omnibus):                  0.825   Jarque-Bera (JB):                0.291
# Skew:                          -0.343   Prob(JB):                        0.865
# Kurtosis:                       2.367   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- NPL/TA Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NPL/TA   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     8.227
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0573
# Time:                        16:51:02   Log-Likelihood:                 38.808
# No. Observations:                   8   AIC:                            -67.62
# Df Residuals:                       3   BIC:                            -67.22
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2268      0.043     -5.308      0.013      -0.363      -0.091
# G scores       0.0006      0.001      1.210      0.313      -0.001       0.002
# G_Lag1         0.0016      0.001      2.480      0.089      -0.000       0.004
# G_Lag2        -0.0005      0.001     -0.557      0.616      -0.003       0.002
# G_Lag3         0.0007      0.001      0.983      0.398      -0.002       0.003
# ==============================================================================
# Omnibus:                        0.988   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.610   Jarque-Bera (JB):                0.568
# Skew:                          -0.575   Prob(JB):                        0.753
# Kurtosis:                       2.381   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- LLP/TA Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 LLP/TA   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     8.967
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):             0.0511
# Time:                        16:51:02   Log-Likelihood:                 54.772
# No. Observations:                   8   AIC:                            -99.54
# Df Residuals:                       3   BIC:                            -99.15
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0088      0.006     -1.510      0.228      -0.027       0.010
# G scores      -0.0002   7.04e-05     -2.726      0.072      -0.000    3.21e-05
# G_Lag1      1.918e-05   8.87e-05      0.216      0.843      -0.000       0.000
# G_Lag2         0.0006      0.000      4.862      0.017       0.000       0.001
# G_Lag3        -0.0003   9.69e-05     -2.967      0.059      -0.001    2.09e-05
# ==============================================================================
# Omnibus:                        1.592   Durbin-Watson:                   2.743
# Prob(Omnibus):                  0.451   Jarque-Bera (JB):                1.025
# Skew:                           0.701   Prob(JB):                        0.599
# Kurtosis:                       1.946   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Liquidity coverage ratio Regression (Governance - G) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Liquidity coverage ratio   R-squared:                       0.873
# Model:                                  OLS   Adj. R-squared:                  0.703
# Method:                       Least Squares   F-statistic:                     5.147
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):              0.105
# Time:                              16:51:02   Log-Likelihood:                -13.120
# No. Observations:                         8   AIC:                             36.24
# Df Residuals:                             3   BIC:                             36.64
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.5477     28.166      1.404      0.255     -50.090     129.185
# G scores      -0.5698      0.342     -1.669      0.194      -1.657       0.517
# G_Lag1         0.1350      0.430      0.314      0.774      -1.234       1.504
# G_Lag2         0.6888      0.556      1.239      0.304      -1.081       2.459
# G_Lag3         0.7286      0.470      1.550      0.219      -0.767       2.225
# ==============================================================================
# Omnibus:                        1.054   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.590   Jarque-Bera (JB):                0.644
# Skew:                          -0.606   Prob(JB):                        0.725
# Kurtosis:                       2.318   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Net stable funding ratio Regression (Governance - G) ---
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Net stable funding ratio   R-squared:                       0.901
# Model:                                  OLS   Adj. R-squared:                  0.768
# Method:                       Least Squares   F-statistic:                     6.788
# Date:                      Thu, 05 Jun 2025   Prob (F-statistic):             0.0738
# Time:                              16:51:02   Log-Likelihood:                -14.003
# No. Observations:                         8   AIC:                             38.01
# Df Residuals:                             3   BIC:                             38.40
# Df Model:                                 4
# Covariance Type:                  nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        179.5751     31.453      5.709      0.011      79.478     279.672
# G scores      -0.8631      0.381     -2.263      0.109      -2.077       0.351
# G_Lag1        -1.6179      0.480     -3.368      0.043      -3.147      -0.089
# G_Lag2         0.8936      0.621      1.439      0.246      -1.083       2.870
# G_Lag3         0.9043      0.525      1.723      0.183      -0.766       2.575
# ==============================================================================
# Omnibus:                        1.628   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.443   Jarque-Bera (JB):                0.790
# Skew:                          -0.726   Prob(JB):                        0.674
# Kurtosis:                       2.487   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Capital Adequacy Ratio Regression (Governance - G) ---
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Capital Adequacy Ratio   R-squared:                       0.964
# Model:                                OLS   Adj. R-squared:                  0.915
# Method:                     Least Squares   F-statistic:                     19.88
# Date:                    Thu, 05 Jun 2025   Prob (F-statistic):             0.0170
# Time:                            16:51:02   Log-Likelihood:                 34.809
# No. Observations:                       8   AIC:                            -59.62
# Df Residuals:                           3   BIC:                            -59.22
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7527      0.070     10.684      0.002       0.528       0.977
# G scores      -0.0023      0.001     -2.670      0.076      -0.005       0.000
# G_Lag1        -0.0019      0.001     -1.738      0.181      -0.005       0.002
# G_Lag2        -0.0013      0.001     -0.907      0.431      -0.006       0.003
# G_Lag3        -0.0007      0.001     -0.624      0.577      -0.004       0.003
# ==============================================================================
# Omnibus:                        0.926   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.573
# Skew:                           0.094   Prob(JB):                        0.751
# Kurtosis:                       1.702   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# --- Leverage Ratio Regression (Governance - G) ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Leverage Ratio   R-squared:                       0.599
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     1.121
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):              0.482
# Time:                        16:51:02   Log-Likelihood:                 38.282
# No. Observations:                   8   AIC:                            -66.56
# Df Residuals:                       3   BIC:                            -66.17
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0238      0.046     -0.522      0.638      -0.169       0.121
# G scores       0.0005      0.001      0.926      0.423      -0.001       0.002
# G_Lag1        -0.0004      0.001     -0.621      0.579      -0.003       0.002
# G_Lag2         0.0005      0.001      0.542      0.626      -0.002       0.003
# G_Lag3         0.0002      0.001      0.297      0.786      -0.002       0.003
# ==============================================================================
# Omnibus:                        0.078   Durbin-Watson:                   2.362
# Prob(Omnibus):                  0.962   Jarque-Bera (JB):                0.289
# Skew:                           0.118   Prob(JB):                        0.866
# Kurtosis:                       2.100   Cond. No.                     7.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
